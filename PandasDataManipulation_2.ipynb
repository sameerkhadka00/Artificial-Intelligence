# %% [markdown]
# ## Data cleaning
#
# In this section, we will take a look at creating, renaming, and dropping columns; type conversion; and sorting &ndash; all of which make our analysis easier. We will be working with the 2019 Yellow Taxi Trip Data provided by NYC Open Data.

# %% [markdown]
# ### Read the data

# %%
import pandas as pd
df = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')

# %% [markdown]
# ##### DIsplaying the column names

# %%
df.columns
# Out:
# Index(['vendorid', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'ratecodeid', 'store_and_fwd_flag',
#        'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %%
df.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# 1            11            26             1         10.5    1.0      0.5
# 2           163           162             1          9.5    1.0      0.5
# 3           170           163             1         13.0    1.0      0.5
# 4           163           236             1         10.5    1.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        7.98          6.12                    0.3         47.90
# 1        0.00          0.00                    0.3         12.30
# 2        2.00          0.00                    0.3         15.80
# 3        4.32          0.00                    0.3         21.62
# 4        0.50          0.00                    0.3         15.30
#
#    congestion_surcharge
# 0                   2.5
# 1                   0.0
# 2                   2.5
# 3                   2.5
# 4                   2.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendorid               10000 non-null  int64
#  1   tpep_pickup_datetime   10000 non-null  object
#  2   tpep_dropoff_datetime  10000 non-null  object
#  3   passenger_count        10000 non-null  int64
#  4   trip_distance          10000 non-null  float64
#  5   ratecodeid             10000 non-null  int64
#  6   store_and_fwd_flag     10000 non-null  object
#  7   pulocationid           10000 non-null  int64
#  8   dolocationid           10000 non-null  int64
#  9   payment_type           10000 non-null  int64
#  10  fare_amount            10000 non-null  float64
#  11  extra                  10000 non-null  float64
#  12  mta_tax                10000 non-null  float64
#  13  tip_amount             10000 non-null  float64
#  14  tolls_amount           10000 non-null  float64
#  15  improvement_surcharge  10000 non-null  float64
#  16  total_amount           10000 non-null  float64
#  17  congestion_surcharge   10000 non-null  float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Dropping columns
# Let's start by dropping the ID columns and the `store_and_fwd_flag` column, which we won't be using.

# %% [raw]
# The dollar sign $
# is used to check if a matching character is the last character in the string. For example, the regular expression (at\.)$ means: a lowercase a, followed by a lowercase t, followed by a . character and the matcher must be at the end of the string.

# %% [markdown]
# "(at\.)" => The fat cat. sat. on the mat.
#
# "(at\.)$" => The fat cat. sat. on the mat.

# %% [markdown]
# ##### Dropping two columns

# %%
df[['vendorid', 'store_and_fwd_flag']]
# Out:
#       vendorid store_and_fwd_flag
# 0            2                  N
# 1            1                  N
# 2            2                  N
# 3            2                  N
# 4            2                  N
# ...        ...                ...
# 9995         1                  N
# 9996         1                  N
# 9997         1                  N
# 9998         1                  N
# 9999         1                  N
#
# [10000 rows x 2 columns]

# %%
new_df= df.drop(['vendorid', 'store_and_fwd_flag'], axis=1)

# %%
new_df
# Out:
#          tpep_pickup_datetime    tpep_dropoff_datetime  passenger_count  \
# 0     2019-10-23T16:39:42.000  2019-10-23T17:14:10.000                1
# 1     2019-10-23T16:32:08.000  2019-10-23T16:45:26.000                1
# 2     2019-10-23T16:08:44.000  2019-10-23T16:21:11.000                1
# 3     2019-10-23T16:22:44.000  2019-10-23T16:43:26.000                1
# 4     2019-10-23T16:45:11.000  2019-10-23T16:58:49.000                1
# ...                       ...                      ...              ...
# 9995  2019-10-23T17:39:59.000  2019-10-23T17:49:26.000                2
# 9996  2019-10-23T17:53:02.000  2019-10-23T18:00:45.000                1
# 9997  2019-10-23T17:07:16.000  2019-10-23T17:11:35.000                1
# 9998  2019-10-23T17:38:26.000  2019-10-23T17:49:28.000                2
# 9999  2019-10-23T17:22:14.000  2019-10-23T17:52:09.000                1
#
#       trip_distance  ratecodeid  pulocationid  dolocationid  payment_type  \
# 0              7.93           1           138           170             1
# 1              2.00           1            11            26             1
# 2              1.36           1           163           162             1
# 3              1.00           1           170           163             1
# 4              1.96           1           163           236             1
# ...             ...         ...           ...           ...           ...
# 9995           1.30           1           238           239             1
# 9996           1.40           1           239           166             2
# 9997           0.70           1           166           152             2
# 9998           2.50           1           151            42             1
# 9999           3.00           1           237            68             1
#
#       fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0            29.5    1.0      0.5        7.98          6.12
# 1            10.5    1.0      0.5        0.00          0.00
# 2             9.5    1.0      0.5        2.00          0.00
# 3            13.0    1.0      0.5        4.32          0.00
# 4            10.5    1.0      0.5        0.50          0.00
# ...           ...    ...      ...         ...           ...
# 9995          8.0    3.5      0.5        2.46          0.00
# 9996          8.0    3.5      0.5        0.00          0.00
# 9997          5.0    1.0      0.5        0.00          0.00
# 9998         10.0    1.0      0.5        0.00          0.00
# 9999         19.0    3.5      0.5        2.50          0.00
#
#       improvement_surcharge  total_amount  congestion_surcharge
# 0                       0.3         47.90                   2.5
# 1                       0.3         12.30                   0.0
# 2                       0.3         15.80                   2.5
# 3                       0.3         21.62                   2.5
# 4                       0.3         15.30                   2.5
# ...                     ...           ...                   ...
# 9995                    0.3         14.76                   2.5
# 9996                    0.3         12.30                   2.5
# 9997                    0.3          6.80                   0.0
# 9998                    0.3         11.80                   0.0
# 9999                    0.3         25.80                   2.5
#
# [10000 rows x 16 columns]

# %% [markdown]
# ##### Saving the modified dataframe into the same file

# %%
new_df.to_csv('/content/2019_Yellow_Taxi_Trip_Data.csv', index=False)

# %%
new_df.columns
# Out:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'ratecodeid', 'pulocationid', 'dolocationid',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge'],
#       dtype='object')

# %% [markdown]
# ##### Displaying the column names after modification

# %%
new_df = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')

# %%
new_df.columns
# Out:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'ratecodeid', 'pulocationid', 'dolocationid',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge'],
#       dtype='object')

# %% [markdown]
# ### Renaming columns
#
# Next, let's rename the datetime columns to 'pickup' and 'dropoff':

# %% [markdown]
# ##### Renaming column names and saving the modified dataframe into the the same file

# %%
n_df=new_df.rename(columns={'tpep_pickup_datetime': 'pickup', 'tpep_dropoff_datetime': 'dropoff'}, inplace=True)

# %%
n_df=new_df.to_csv('/content/2019_Yellow_Taxi_Trip_Data.csv', index=False)

# %%
n_df = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')

# %%
n_df.columns
# Out:
# Index(['pickup', 'dropoff', 'passenger_count', 'trip_distance', 'ratecodeid',
#        'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %% [markdown]
# ##### Displaying the column names

# %% [markdown]
# ### Type conversion
#
# Notice anything off with the data types?

# %%
n_df.dtypes
# Out:
# pickup                    object
# dropoff                   object
# passenger_count            int64
# trip_distance            float64
# ratecodeid                 int64
# pulocationid               int64
# dolocationid               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %% [markdown]
# Both `pickup` and `dropoff` should be stored as datetimes. Let's fix this:

# %%
n_df['pickup'] = pd.to_datetime(n_df['pickup'], format='%Y-%m-%d')

# %%
n_df['dropoff'] = pd.to_datetime(n_df['pickup'], format='%Y-%m-%d')

# %%
n_df.dtypes
# Out:
# pickup                   datetime64[ns]
# dropoff                  datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# ratecodeid                        int64
# pulocationid                      int64
# dolocationid                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %% [markdown]
# ### Creating new columns
#
# Let's calculate the following for each row:
#
# 1. elapsed time of the trip
# 2. the tip percentage
# 3. the total taxes, tolls, fees, and surcharges
# 4. the average speed of the taxi

# %%
n_df['elapsed_time_minutes'] = (n_df['dropoff'] - n_df['pickup'])

# %%
n_df.head()
# Out:
#                pickup             dropoff  passenger_count  trip_distance  \
# 0 2019-10-23 16:39:42 2019-10-23 16:39:42                1           7.93
# 1 2019-10-23 16:32:08 2019-10-23 16:32:08                1           2.00
# 2 2019-10-23 16:08:44 2019-10-23 16:08:44                1           1.36
# 3 2019-10-23 16:22:44 2019-10-23 16:22:44                1           1.00
# 4 2019-10-23 16:45:11 2019-10-23 16:45:11                1           1.96
#
#    ratecodeid  pulocationid  dolocationid  payment_type  fare_amount  extra  \
# 0           1           138           170             1         29.5    1.0
# 1           1            11            26             1         10.5    1.0
# 2           1           163           162             1          9.5    1.0
# 3           1           170           163             1         13.0    1.0
# 4           1           163           236             1         10.5    1.0
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5        7.98          6.12                    0.3         47.90
# 1      0.5        0.00          0.00                    0.3         12.30
# 2      0.5        2.00          0.00                    0.3         15.80
# 3      0.5        4.32          0.00                    0.3         21.62
# 4      0.5        0.50          0.00                    0.3         15.30
#
#    congestion_surcharge  elapsed_time_minutes
# 0                   2.5                   0.0
# 1                   0.0                   0.0
# 2                   2.5                   0.0
# 3                   2.5                   0.0
# 4                   2.5                   0.0

# %%
n_df['tip_percentage'] = (n_df['tip_amount'] / n_df['fare_amount']) * 100

# %%
n_df['total_taxes_tolls_fees'] = n_df['tolls_amount'] + n_df['total_amount'] - n_df['fare_amount']

# %%
n_df['average_speed_mph'] = n_df['trip_distance'] / (n_df['elapsed_time_minutes'] / 60)

# %%
n_df.head()
# Out:
#                pickup             dropoff  passenger_count  trip_distance  \
# 0 2019-10-23 16:39:42 2019-10-23 16:39:42                1           7.93
# 1 2019-10-23 16:32:08 2019-10-23 16:32:08                1           2.00
# 2 2019-10-23 16:08:44 2019-10-23 16:08:44                1           1.36
# 3 2019-10-23 16:22:44 2019-10-23 16:22:44                1           1.00
# 4 2019-10-23 16:45:11 2019-10-23 16:45:11                1           1.96
#
#    ratecodeid  pulocationid  dolocationid  payment_type  fare_amount  extra  \
# 0           1           138           170             1         29.5    1.0
# 1           1            11            26             1         10.5    1.0
# 2           1           163           162             1          9.5    1.0
# 3           1           170           163             1         13.0    1.0
# 4           1           163           236             1         10.5    1.0
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5        7.98          6.12                    0.3         47.90
# 1      0.5        0.00          0.00                    0.3         12.30
# 2      0.5        2.00          0.00                    0.3         15.80
# 3      0.5        4.32          0.00                    0.3         21.62
# 4      0.5        0.50          0.00                    0.3         15.30
#
#    congestion_surcharge  elapsed_time_minutes  tip_percentage  \
# 0                   2.5                   0.0       27.050847
# 1                   0.0                   0.0        0.000000
# 2                   2.5                   0.0       21.052632
# 3                   2.5                   0.0       33.230769
# 4                   2.5                   0.0        4.761905
#
#    total_taxes_tolls_fees  average_speed_mph
# 0                   24.52                inf
# 1                    1.80                inf
# 2                    6.30                inf
# 3                    8.62                inf
# 4                    4.80                inf

# %%
#importing pandas and numpy libraries
import pandas as pd
import numpy as np

# creating and initializing a nested list
values_list = [[15, 2.5, 100], [20, 4.5, 50], [25, 5.2, 80],
               [45, 5.8, 48], [40, 6.3, 70], [41, 6.4, 90],
               [51, 2.3, 111]]

# creating a pandas dataframe
df = pd.DataFrame(values_list, columns=['Field_1', 'Field_2', 'Field_3'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])

# Apply function numpy.square() to square
# the values of one row only i.e. row
# with index name 'd'

# %%
# importing pandas and numpylibraries
import pandas as pd
import numpy as np

# creating and initializing a nested list
values_list = [[1.5, 2.5, 10.0], [2.0, 4.5, 5.0], [2.5, 5.2, 8.0],
               [4.5, 5.8, 4.8], [4.0, 6.3, 70], [4.1, 6.4, 9.0],
               [5.1, 2.3, 11.1]]

# creating a pandas dataframe
df = pd.DataFrame(values_list, columns=['Field_1', 'Field_2', 'Field_3'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])
# Apply function numpy.square() to square
# the values of 2 rows only i.e. with row
# index name 'b' and 'f' only

# %% [markdown]
# ### Sorting by values
#
# We can use the `sort_values()` method to sort based on any number of columns:

# %% [markdown]
# ### [Exercise 2.1](./workbook.ipynb#Exercise-2.1)
#
# ##### Read in the meteorite data from the `Meteorite_Landings.csv` file, rename the `mass (g)` column to `mass`, and drop all the latitude and longitude columns. Sort the result by mass in descending order.

# %% [markdown]
# ##### Load the CSV file into a DataFrame

# %%
import pandas as pd
meteorites = pd.read_csv(r'Meteorite_Landings.csv')

# %%
meteorites.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %% [markdown]
# ##### Rename the mass (g) column to mass

# %%
meteorites.rename(columns={'mass (g)': 'mass'}, inplace=True)

# %% [markdown]
# ##### Drop latitude and longitude columns

# %%
meteorites.drop(['reclat', 'reclong', 'GeoLocation'], axis=1, inplace=True)

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year'], dtype='object')

# %% [markdown]
# ##### Sort the DataFrame by mass in descending order

# %%
meteorites.sort_values(['mass'], ascending=False, inplace=True)

# %% [markdown]
# ##### Storing the modified dataframe into the same file

# %%
meteorites.to_csv('/content/Meteorites_Landings.csv', index=False)

# %% [markdown]
# ##### Displaying the data here (for the reference purpose) from the modified file

# %%
meteorites.head()
# Out:
#                   name     id nametype      recclass        mass   fall  \
# 16392             Hoba  11890    Valid     Iron, IVB  60000000.0  Found
# 5373         Cape York   5262    Valid   Iron, IIIAB  58200000.0  Found
# 5365   Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 5370     Canyon Diablo   5257    Valid  Iron, IAB-MG  30000000.0  Found
# 3455           Armanty   2335    Valid    Iron, IIIE  28000000.0  Found
#
#                          year
# 16392  01/01/1920 12:00:00 AM
# 5373   01/01/1818 12:00:00 AM
# 5365   12/22/1575 12:00:00 AM
# 5370   01/01/1891 12:00:00 AM
# 3455   01/01/1898 12:00:00 AM
